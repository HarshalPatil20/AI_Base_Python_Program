# %%
import cv2
import imutils

# %%
#redLower=(157,93,203)
#redUpper=(179,255,255)

# %%
redLower=(0,193,98)
redUpper=(179,255,255)

# %%
camera=cv2.VideoCapture(0)

# %%
while True:
    (grabbed,frame)=camera.read()
    frame=imutils.resize(frame,width=600)
    blurred=cv2.GaussianBlur(frame,(11,11),0)
    hsv=cv2.cvtColor(blurred,cv2.COLOR_BGR2HSV)
    
    mask=cv2.inRange(hsv,redLower,redUpper)
    mask=cv2.erode(mask,None,iterations=2)
    mask=cv2.dilate(mask,None,iterations=2)
    
    cnts=cv2.findContours(mask.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)[-2]
    center=None
    if len(cnts)>0:
        c=max(cnts,key=cv2.contourArea)
        ((x,y),radius)=cv2.minEnclosingCircle(c)
        M=cv2.moments(c)
        center=(int(M["m10"]/M["m00"]),int(M["m01"]/M["m00"]))
        if radius>10:
            cv2.circle(frame,(int(x),int(y)),int(radius),(0,255,255),2)
            cv2.circle(frame,center,5,(0,0,255),-1)
            print(center,radius)
            if radius>250:
                print("stop")
            else:
                if(center[0]<150):
                    print("Left")
                    
                elif(center[0]>450):
                    print("Right")
                elif(radius<250):
                    print("Front")
                else:
                    print("Stop")
cv2.imshow("Frame",frame)
key=cv2.waitKey(1) & 0xFF
if key==ord("q"):
    break
    
    
camera.release()
cv2.destroyALLWindows()
# Out:
# (588, 56) 24.622243881225586
# Right
# (588, 56) 24.622243881225586
# Right
# (590, 63) 12.201313972473145
# Right
# (590, 63) 12.201313972473145
# Right
# (589, 58) 16.324926376342773
# Right
# (589, 58) 16.324926376342773
# Right
# (593, 80) 18.180612564086914
# Right
# (593, 80) 18.180612564086914
# Right
# (588, 50) 26.386648178100586
# Right
# (588, 50) 26.386648178100586
# Right
# (588, 42) 10.519909858703613
# Right
# (588, 42) 10.519909858703613
# Right
# (590, 59) 33.0493049621582
# Right
# (590, 59) 33.0493049621582
# Right
# (584, 30) 21.76601219177246
# Right
# (584, 30) 21.76601219177246
# Right
# (585, 35) 14.030193328857422
# Right
# (585, 35) 14.030193328857422
# Right
# (585, 35) 14.090692520141602
# Right
# (585, 35) 14.090692520141602
# Right
# (591, 71) 26.476503372192383
# Right
# (591, 71) 26.476503372192383
# Right
# (585, 33) 13.729630470275879
# Right
# (585, 33) 13.729630470275879
# Right
# (591, 75) 20.24855613708496
# Right
# (591, 75) 20.24855613708496
# Right
# (587, 54) 23.12153434753418
# Right
# (587, 54) 23.12153434753418
# Right
# (590, 67) 13.086352348327637
# Right
# (590, 67) 13.086352348327637
# Right
# (582, 37) 10.969269752502441
# Right
# (593, 91) 11.646387100219727
# Right
# (593, 91) 11.646387100219727
# Right
# (593, 79) 20.74256706237793
# Right
# (593, 79) 20.74256706237793
# Right
# (588, 57) 23.505416870117188
# Right
# (591, 74) 21.931812286376953
# Right
# (591, 74) 21.931812286376953
# Right
# (585, 47) 52.68074035644531
# Right
# (585, 47) 52.68074035644531
# Right
# (586, 47) 51.54619598388672
# Right
# (586, 47) 51.54619598388672
# Right
# (586, 49) 52.54056167602539
# Right
# (586, 49) 52.54056167602539
# Right
# (586, 50) 49.965087890625
# Right
# (586, 50) 49.965087890625
# Right
# (586, 48) 54.251827239990234
# Right
# (586, 48) 54.251827239990234
# Right
# (585, 47) 53.92829132080078
# Right
# (585, 47) 53.92829132080078
# Right
# (587, 52) 50.000099182128906
# Right
# (587, 52) 50.000099182128906
# Right
# (586, 49) 53.50243377685547
# Right
# (586, 49) 53.50243377685547
# Right
# (588, 54) 47.676090240478516
# Right
# (588, 54) 47.676090240478516
# Right
# (587, 50) 50.825782775878906
# Right
# (587, 50) 50.825782775878906
# Right
# (586, 49) 53.758819580078125
# Right
# (586, 49) 53.758819580078125
# Right
# (581, 31) 22.638561248779297
# Right
# (581, 31) 22.638561248779297
# Right
# (581, 31) 22.638561248779297
# Right
# (579, 26) 24.413209915161133
# Right
# (579, 26) 24.413209915161133
# Right
# (588, 57) 42.00605010986328
# Right
# (588, 57) 42.00605010986328
# Right
# (585, 49) 52.652259826660156
# Right
# (585, 49) 52.652259826660156
# Right
# (587, 55) 62.84315872192383
# Right
# (587, 55) 62.84315872192383
# Right
# (587, 48) 54.08567810058594
# Right
# (587, 48) 54.08567810058594
# Right
# (584, 32) 25.26865577697754
# Right
# (584, 32) 25.26865577697754
# Right
# (584, 38) 38.684722900390625
# Right
# (584, 38) 38.684722900390625
# Right
# (585, 49) 53.758819580078125
# Right
# (585, 49) 53.758819580078125
# Right
# (586, 48) 53.02132034301758
# Right
# (586, 48) 53.02132034301758
# Right
# (587, 45) 33.20401382446289
# Right
# (587, 45) 33.20401382446289
# Right
# (585, 47) 54.23339080810547
# Right
# (585, 47) 54.23339080810547
# Right
# (586, 49) 54.083370208740234
# Right
# (586, 49) 54.083370208740234
# Right
# (585, 46) 56.773773193359375
# Right
# (585, 46) 56.773773193359375
# Right
# (585, 48) 51.22997283935547
# Right
# (585, 48) 51.22997283935547
# Right
# (585, 51) 52.81108474731445
# Right
# (585, 51) 52.81108474731445
# Right
# (585, 47) 55.32188415527344
# Right
# (585, 47) 55.32188415527344
# Right
# (587, 52) 53.758819580078125
# Right
# (587, 52) 53.758819580078125
# Right
# (588, 55) 45.47811508178711
# Right
# (588, 55) 45.47811508178711
# Right
# (591, 65) 36.58219909667969
# Right
# (591, 65) 36.58219909667969
# Right
# (592, 79) 23.889272689819336
# Right
# (592, 79) 23.889272689819336
# Right
# (584, 35) 15.945319175720215
# Right
# (584, 35) 15.945319175720215
# Right
# (581, 29) 12.43875789642334
# Right
# (581, 29) 12.43875789642334
# Right
# (590, 64) 15.508162498474121
# Right
# (590, 64) 15.508162498474121
# Right
# (591, 76) 23.048959732055664
# Right
# (591, 76) 23.048959732055664
# Right
# (592, 77) 22.67717933654785
# Right
# (592, 77) 22.67717933654785
# Right
# (590, 66) 10.462411880493164
# Right
# (590, 66) 10.462411880493164
# Right
# (583, 31) 15.706021308898926
# Right
# (583, 31) 15.706021308898926
# Right
# (591, 63) 12.499685287475586
# Right
# (591, 63) 12.499685287475586
# Right
# (590, 63) 13.124505043029785
# Right
# (590, 63) 13.124505043029785
# Right
# (591, 66) 10.63024616241455
# Right
# (591, 66) 10.63024616241455
# Right
# (592, 77) 17.745548248291016
# Right
# (592, 77) 17.745548248291016
# Right
# (581, 28) 11.768702507019043
# Right
# (581, 28) 11.768702507019043
# Right
# (591, 77) 20.169111251831055
# Right
# (591, 77) 20.169111251831055
# Right
# (587, 36) 17.46578025817871
# Right
# (587, 36) 17.46578025817871
# Right
# (590, 64) 11.710886001586914
# Right
# (590, 64) 11.710886001586914
# Right
# (590, 71) 14.333642959594727
# Right
# (588, 54) 20.178443908691406
# Right
# (588, 54) 20.178443908691406
# Right
# (592, 68) 12.103818893432617
# Right
# (592, 68) 12.103818893432617
# Right
# (591, 63) 16.140111923217773
# Right
# (591, 63) 16.140111923217773
# Right
# (589, 67) 13.086352348327637
# Right
# (589, 67) 13.086352348327637
# Right
# (589, 61) 14.79793643951416
# Right
# (589, 61) 14.79793643951416
# Right
# (590, 63) 14.399763107299805
# Right
# (590, 63) 14.399763107299805
# Right
# (588, 54) 21.58713150024414
# Right
# (588, 54) 21.58713150024414
# Right
# (584, 35) 18.721744537353516
# Right
# (584, 35) 18.721744537353516
# Right
# (590, 67) 36.6231803894043
# Right
# (590, 67) 36.6231803894043
# Right
# (591, 64) 15.66055965423584
# Right
# (591, 64) 15.66055965423584
# Right
# (592, 75) 27.29478645324707
# Right
# (592, 75) 27.29478645324707
# Right
# (591, 76) 20.941368103027344
# Right
# (591, 76) 20.941368103027344
# Right
# (588, 53) 28.306459426879883
# Right
# (588, 53) 28.306459426879883
# Right
# (591, 78) 19.31330680847168
# Right
# (591, 78) 19.31330680847168
# Right
# (586, 38) 15.041708946228027
# Right
# (586, 38) 15.041708946228027
# Right
# (591, 74) 28.28437042236328
# Right
# (590, 65) 10.965956687927246
# Right
# (590, 65) 10.965956687927246
# Right
# (595, 90) 11.180439949035645
# Right
# (595, 90) 11.180439949035645
# Right
# (592, 63) 12.209755897521973
# Right
# (592, 63) 12.209755897521973
# Right
# (592, 71) 15.264437675476074
# Right
# (592, 71) 15.264437675476074
# Right
# (593, 79) 16.55304527282715
# Right
# (593, 79) 16.55304527282715
# Right
# (592, 77) 18.581003189086914
# Right
# (592, 77) 18.581003189086914
# Right
# (594, 70) 10.770429611206055
# Right
# (594, 70) 10.770429611206055
# Right
# (589, 57) 38.8105354309082
# Right
# (589, 57) 38.8105354309082
# Right
# (591, 63) 34.005367279052734
# Right
# (591, 63) 34.005367279052734
# Right
# (590, 69) 12.379518508911133
# Right
# (590, 69) 12.379518508911133
# Right
# (592, 78) 18.581003189086914
# Right
# (592, 78) 18.581003189086914
# Right
# (593, 78) 18.696910858154297
# Right
# (593, 78) 18.696910858154297
# Right
# (593, 78) 18.696910858154297
# Right
# (593, 73) 32.062538146972656
# Right
# (593, 73) 32.062538146972656
# Right
# (593, 74) 27.04173469543457
# Right
# (593, 74) 27.04173469543457
# Right
# (593, 75) 21.86902618408203
# Right
# (593, 75) 21.86902618408203
# Right
# (591, 63) 15.811488151550293
# Right
# (591, 63) 15.811488151550293
# Right
# (592, 63) 40.94213104248047
# Right
# (592, 63) 40.94213104248047
# Right
# (589, 50) 32.25688171386719
# Right
# (589, 50) 32.25688171386719
# Right
# (580, 18) 10.295730590820312
# Right
# (580, 18) 10.295730590820312
# Right
# (591, 69) 12.500100135803223
# Right
# (591, 69) 12.500100135803223
# Right
# (592, 74) 25.811918258666992
# Right
# (592, 74) 25.811918258666992
# Right
# (592, 72) 32.16374206542969
# Right
# (592, 72) 32.16374206542969
# Right
# (584, 31) 27.10175895690918
# Right
# (584, 31) 27.10175895690918
# Right
# (590, 62) 40.62644577026367
# Right
# (590, 62) 40.62644577026367
# Right
# (593, 82) 22.192440032958984
# Right
# (593, 82) 22.192440032958984
# Right
# (592, 78) 21.082136154174805
# Right
# (592, 78) 21.082136154174805
# Right
# (591, 63) 39.386009216308594
# Right
# (591, 63) 39.386009216308594
# Right
# (590, 58) 38.12161636352539
# Right
# (590, 58) 38.12161636352539
# Right
# (591, 61) 35.654693603515625
# Right
# (591, 61) 35.654693603515625
# Right
# (591, 65) 31.4086971282959
# Right
# (591, 65) 31.4086971282959
# Right
# (588, 58) 41.62040710449219
# Right
# (588, 58) 41.62040710449219
# Right
# (587, 53) 45.235595703125
# Right
# (587, 53) 45.235595703125
# Right
# (590, 57) 23.307823181152344
# Right
# (590, 57) 23.307823181152344
# Right
# (588, 48) 37.80552291870117
# Right
# (588, 48) 37.80552291870117
# Right
# (592, 80) 23.24370002746582
# Right
# (592, 80) 23.24370002746582
# Right
# (589, 58) 41.14010238647461
# Right
# (589, 58) 41.14010238647461
# Right
# (585, 42) 45.188594818115234
# Right
# (585, 42) 45.188594818115234
# Right
# (587, 48) 47.67084503173828
# Right
# (587, 48) 47.67084503173828
# Right
# (588, 56) 42.32326126098633
# Right
# (588, 56) 42.32326126098633
# Right
# (589, 60) 40.02821350097656
# Right
# (589, 60) 40.02821350097656
# Right
# (586, 38) 17.241039276123047
# Right
# (586, 38) 17.241039276123047
# Right
# (589, 57) 48.50783157348633
# Right
# (589, 57) 48.50783157348633
# Right
# (589, 62) 42.69084930419922
# Right
# (589, 62) 42.69084930419922
# Right
# (590, 64) 33.860103607177734
# Right
# (590, 64) 33.860103607177734
# Right
# (589, 59) 38.37978744506836
# Right
# (589, 59) 38.37978744506836
# Right
# (587, 52) 41.14010238647461
# Right
# (587, 52) 41.14010238647461
# Right
# (587, 50) 49.34075164794922
# Right
# (587, 50) 49.34075164794922
# Right
# (592, 81) 25.811918258666992
# Right
# (592, 81) 25.811918258666992
# Right
# (588, 54) 47.6682243347168
# Right
# (588, 54) 47.6682243347168
# Right
# (588, 54) 45.26045608520508
# Right
# (588, 54) 45.26045608520508
# Right
# (588, 53) 46.32503890991211
# Right
# (588, 53) 46.32503890991211
# Right
# (588, 55) 48.50783157348633
# Right
# (588, 55) 48.50783157348633
# Right
# (588, 55) 49.48999786376953
# Right
# (588, 55) 49.48999786376953
# Right
# (590, 62) 38.396060943603516
# Right
# (590, 62) 38.396060943603516
# Right
# (588, 53) 60.87702560424805
# Right
# (588, 53) 60.87702560424805
# Right
# (588, 54) 49.13511657714844
# Right
# (588, 54) 49.13511657714844
# Right
# (588, 55) 49.117305755615234
# Right
# (588, 55) 49.117305755615234
# Right
# (590, 61) 38.564979553222656
# Right
# (590, 61) 38.564979553222656
# Right
# (590, 59) 39.51015090942383
# Right
# (590, 59) 39.51015090942383
# Right
# (589, 54) 48.15090560913086
# Right
# (589, 54) 48.15090560913086
# Right
# (584, 30) 23.717182159423828
# Right
# (584, 30) 23.717182159423828
# Right
# (592, 69) 34.00377655029297
# Right
# (592, 69) 34.00377655029297
# Right
# (591, 63) 33.0493049621582
# Right
# (591, 63) 33.0493049621582
# Right
# (591, 64) 14.6771240234375
# Right
# (591, 64) 14.6771240234375
# Right
# (589, 55) 29.34716033935547
# Right
# (589, 55) 29.34716033935547
# Right
# (590, 57) 25.739173889160156
# Right
# (590, 57) 25.739173889160156
# Right
# (592, 74) 21.28976821899414
# Right
# (592, 74) 21.28976821899414
# Right
# (589, 58) 38.89739990234375
# Right
# (589, 58) 38.89739990234375
# Right
# (592, 61) 22.964786529541016
# Right
# (592, 61) 22.964786529541016
# Right
# (589, 59) 41.28266143798828
# Right
# (589, 59) 41.28266143798828
# Right
# (588, 59) 40.67257308959961
# Right
# (588, 59) 40.67257308959961
# Right
# (588, 59) 40.67257308959961
# Right
# (588, 55) 50.1224479675293
# Right
# (589, 51) 31.197053909301758
# Right
# (589, 51) 31.197053909301758
# Right
# (591, 65) 35.28820037841797
# Right
# (591, 65) 35.28820037841797
# Right
# (592, 72) 25.495197296142578
# Right
# (592, 72) 25.495197296142578
# Right
# (590, 64) 16.620868682861328
# Right
# (590, 64) 16.620868682861328
# Right
# (590, 64) 15.811488151550293
# Right
# (590, 64) 15.811488151550293
# Right
# (590, 59) 36.58219909667969
# Right
# (590, 59) 36.58219909667969
# Right
# (588, 50) 29.12483024597168
# Right
# (588, 50) 29.12483024597168
# Right
# (587, 47) 35.28820037841797
# Right
# (587, 47) 35.28820037841797
# Right
# (588, 42) 14.78051471710205
# Right
# (588, 42) 14.78051471710205
# Right
# (591, 69) 12.747649192810059
# Right
# (591, 69) 12.747649192810059
# Right
# (589, 53) 43.41668701171875
# Right
# (589, 53) 43.41668701171875
# Right
# (591, 66) 32.756778717041016
# Right
# (591, 66) 32.756778717041016
# Right
# (590, 51) 28.79245948791504
# Right
# (590, 51) 28.79245948791504
# Right
# (589, 53) 26.7442569732666
# Right
# (589, 53) 26.7442569732666
# Right
# (591, 66) 36.28025817871094
# Right
# (591, 66) 36.28025817871094
# Right
# (590, 65) 12.747649192810059
# Right
# (590, 65) 12.747649192810059
# Right
# (590, 60) 33.5328369140625
# Right
# (590, 60) 33.5328369140625
# Right
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-bdfd9be2d4c5> in <module>
#       1 while True:
# ----> 2     (grabbed,frame)=camera.read()
#       3     frame=imutils.resize(frame,width=600)
#       4     blurred=cv2.GaussianBlur(frame,(11,11),0)
#       5     hsv=cv2.cvtColor(blurred,cv2.COLOR_BGR2HSV)
#
# KeyboardInterrupt:
